# %%
import yfinance as yf 
import talib as ta  
import numpy as np 
import matplotlib.pyplot as plt
from talib.abstract import *

# %%
def check_cdl_3_line(df):
    a = CDL3LINESTRIKE(df)
    for aa in a:
        if(aa != 0):
            print(aa)
            return True
    return False

# %%
df = yf.download('GIB',start='2021-05-19',end = '2021-05-26',interval='1m') #start='2021-05-25',end = '2021-05-26'
df.columns = df.columns.str.lower()   

#print(df.head())

#close_rsi = ta.RSI(df['close'])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.plot(df['close'])
plt.plot(close_rsi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8ef1e1a78336> in <module>
#       1 plt.plot(df['close'])
# ----> 2 plt.plot(close_rsi)
#
# NameError: name 'close_rsi' is not defined

# %%
out = SMA(df, timeperiod=25)
plt.plot(x = df.set_index(),df['close'])
plt.plot(out)

# %%
ta.get_functions()
a = CDL3LINESTRIKE(df)
for aa in a:
    if(aa != 0):
        print(aa)
